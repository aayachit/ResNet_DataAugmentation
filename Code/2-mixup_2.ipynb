# %%
from __future__ import print_function
import numpy as np

import keras
from keras.datasets import cifar10
from keras.layers import AveragePooling2D, Input, Flatten
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.callbacks import ReduceLROnPlateau
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
from keras.models import Model
import os

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Mixup Augmentation

# %%
class MixupAugmentation():
    def __init__(self, X_train, y_train, batch_size=32, alpha=0.2, shuffle=True):
        self.X_train = X_train
        self.y_train = y_train
        self.batch_size = batch_size
        self.alpha = alpha
        self.shuffle = shuffle
        self.sample_num = len(X_train)
      

    def __call__(self):
        while True:
            indexes = self.__get_exploration_order()
            itr_num = int(len(indexes) // (self.batch_size * 2))

            for i in range(itr_num):
                batch_ids = indexes[i * self.batch_size * 2:(i + 1) * self.batch_size * 2]
                X, y = self.__data_generation(batch_ids)

                yield X, y

    def __get_exploration_order(self):
        indexes = np.arange(self.sample_num)

        if self.shuffle:
            np.random.shuffle(indexes)

        return indexes

    def __data_generation(self, batch_ids):
        _, h, w, c = self.X_train.shape
        l = np.random.beta(self.alpha, self.alpha, self.batch_size)
        X_l = l.reshape(self.batch_size, 1, 1, 1)
        y_l = l.reshape(self.batch_size, 1)

        X1 = self.X_train[batch_ids[:self.batch_size]]
        X2 = self.X_train[batch_ids[self.batch_size:]]
        X = X1 * X_l + X2 * (1 - X_l)


        if isinstance(self.y_train, list):
            y = []

            for y_train_ in self.y_train:
                y1 = y_train_[batch_ids[:self.batch_size]]
                y2 = y_train_[batch_ids[self.batch_size:]]
                y.append(y1 * y_l + y2 * (1 - y_l))
        else:
            y1 = self.y_train[batch_ids[:self.batch_size]]
            y2 = self.y_train[batch_ids[self.batch_size:]]
            y = y1 * y_l + y2 * (1 - y_l)

        return X, y

# %% [markdown]
# RESNET20

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

 

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v2(input_shape, depth, num_classes=10):
    
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# Data Preparation

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

input_shape = x_train.shape[1:]

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

x_train, X_test, y_train, Y_test = train_test_split(x_train, y_train, stratify=y_train, test_size=0.8)

N = 10

y_train = keras.utils.to_categorical(y_train, N)
y_test = keras.utils.to_categorical(y_test, N)

# %% [markdown]
# Training Parameters

# %%
batch_size = 128 
epochs = 100
#N = 10

n=3
depth = n*6+2
model_type = 'ResNet%dv' % (depth)

# %% [markdown]
# Model

# %%
model = resnet_v2(input_shape=input_shape, depth=depth)


model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

#Augmentation
mixup_generator = MixupAugmentation(x_train, y_train, batch_size=batch_size, alpha=0.2)()

plot = model.fit_generator(generator=mixup_generator,
                        steps_per_epoch=x_train.shape[0] // batch_size,
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1
                        )

scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Epoch 1/100
# 78/78 [==============================] - 21s 269ms/step - loss: 2.2806 - accuracy: 0.3512 - val_loss: 2.7900 - val_accuracy: 0.1778
# Epoch 2/100
# 78/78 [==============================] - 10s 125ms/step - loss: 1.9842 - accuracy: 0.4663 - val_loss: 2.9603 - val_accuracy: 0.2087
# Epoch 3/100
# 78/78 [==============================] - 10s 125ms/step - loss: 1.8045 - accuracy: 0.5484 - val_loss: 3.3185 - val_accuracy: 0.2168
# Epoch 4/100
# 78/78 [==============================] - 10s 126ms/step - loss: 1.6855 - accuracy: 0.5870 - val_loss: 2.0392 - val_accuracy: 0.3920
# Epoch 5/100
# 78/78 [==============================] - 10s 126ms/step - loss: 1.5763 - accuracy: 0.6340 - val_loss: 2.1537 - val_accuracy: 0.3759
# Epoch 6/100
# 78/78 [==============================] - 10s 127ms/step - loss: 1.4917 - accuracy: 0.6672 - val_loss: 1.9852 - val_accuracy: 0.4373
# Epoch 7/100
# 78/78 [==============================] - 10s 127ms/step - loss: 1.3779 - accuracy: 0.7159 - val_loss: 2.0202 - val_accuracy: 0.4270
# Epoch 8/100
# 78/78 [==============================] - 10s 127ms/step - loss: 1.3095 - accuracy: 0.7515 - val_loss: 2.1939 - val_accuracy: 0.4247
# Epoch 9/100
# 78/78 [==============================] - 10s 128ms/step - loss: 1.2447 - accuracy: 0.7798 - val_loss: 2.2862 - val_accuracy: 0.4345
# Epoch 10/100
# 78/78 [==============================] - 10s 128ms/step - loss: 1.1839 - accuracy: 0.8033 - val_loss: 1.8093 - val_accuracy: 0.4996
# Epoch 11/100
# 78/78 [==============================] - 10s 129ms/step - loss: 1.1120 - accuracy: 0.8279 - val_loss: 2.1651 - val_accuracy: 0.4350
# Epoch 12/100
# 78/78 [==============================] - 10s 129ms/step - loss: 1.0553 - accuracy: 0.8551 - val_loss: 1.8048 - val_accuracy: 0.5275
# Epoch 13/100
# 78/78 [==============================] - 10s 128ms/step - loss: 1.0358 - accuracy: 0.8608 - val_loss: 1.7519 - val_accuracy: 0.5342
# Epoch 14/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.9887 - accuracy: 0.8775 - val_loss: 2.1834 - val_accuracy: 0.4846
# Epoch 15/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.9863 - accuracy: 0.8814 - val_loss: 2.2732 - val_accuracy: 0.4265
# Epoch 16/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.9549 - accuracy: 0.8938 - val_loss: 2.2199 - val_accuracy: 0.4373
# Epoch 17/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.9336 - accuracy: 0.9008 - val_loss: 2.3824 - val_accuracy: 0.4267
# Epoch 18/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.9139 - accuracy: 0.9015 - val_loss: 1.8110 - val_accuracy: 0.5499
# Epoch 19/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8915 - accuracy: 0.9090 - val_loss: 1.6364 - val_accuracy: 0.5699
# Epoch 20/100
# 78/78 [==============================] - 10s 129ms/step - loss: 0.8868 - accuracy: 0.9123 - val_loss: 1.8977 - val_accuracy: 0.5195
# Epoch 21/100
# 78/78 [==============================] - 10s 129ms/step - loss: 0.8803 - accuracy: 0.9141 - val_loss: 2.2305 - val_accuracy: 0.4144
# Epoch 22/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8670 - accuracy: 0.9159 - val_loss: 2.3845 - val_accuracy: 0.4644
# Epoch 23/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8636 - accuracy: 0.9134 - val_loss: 1.8860 - val_accuracy: 0.5175
# Epoch 24/100
# 78/78 [==============================] - 10s 129ms/step - loss: 0.8587 - accuracy: 0.9139 - val_loss: 2.0153 - val_accuracy: 0.5055
# Epoch 25/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8434 - accuracy: 0.9206 - val_loss: 1.9514 - val_accuracy: 0.4906
# Epoch 26/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8401 - accuracy: 0.9202 - val_loss: 2.6600 - val_accuracy: 0.3716
# Epoch 27/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8281 - accuracy: 0.9232 - val_loss: 1.6687 - val_accuracy: 0.5684
# Epoch 28/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8321 - accuracy: 0.9206 - val_loss: 2.0714 - val_accuracy: 0.5085
# Epoch 29/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8126 - accuracy: 0.9276 - val_loss: 2.0535 - val_accuracy: 0.5083
# Epoch 30/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8148 - accuracy: 0.9287 - val_loss: 1.7539 - val_accuracy: 0.5408
# Epoch 31/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8152 - accuracy: 0.9270 - val_loss: 2.0158 - val_accuracy: 0.5053
# Epoch 32/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8144 - accuracy: 0.9228 - val_loss: 3.4765 - val_accuracy: 0.3069
# Epoch 33/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.8163 - accuracy: 0.9261 - val_loss: 1.8021 - val_accuracy: 0.5445
# Epoch 34/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.8041 - accuracy: 0.9288 - val_loss: 2.3606 - val_accuracy: 0.4445
# Epoch 35/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.8016 - accuracy: 0.9306 - val_loss: 1.8826 - val_accuracy: 0.5377
# Epoch 36/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7975 - accuracy: 0.9293 - val_loss: 1.6905 - val_accuracy: 0.5480
# Epoch 37/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7776 - accuracy: 0.9350 - val_loss: 2.6901 - val_accuracy: 0.4108
# Epoch 38/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7791 - accuracy: 0.9323 - val_loss: 1.8317 - val_accuracy: 0.5000
# Epoch 39/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7849 - accuracy: 0.9314 - val_loss: 1.5151 - val_accuracy: 0.5897
# Epoch 40/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7820 - accuracy: 0.9295 - val_loss: 1.9806 - val_accuracy: 0.4996
# Epoch 41/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7755 - accuracy: 0.9336 - val_loss: 1.9445 - val_accuracy: 0.5165
# Epoch 42/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7776 - accuracy: 0.9290 - val_loss: 1.7972 - val_accuracy: 0.5314
# Epoch 43/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7742 - accuracy: 0.9331 - val_loss: 2.2960 - val_accuracy: 0.4639
# Epoch 44/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7654 - accuracy: 0.9320 - val_loss: 1.8834 - val_accuracy: 0.5087
# Epoch 45/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7766 - accuracy: 0.9342 - val_loss: 1.9620 - val_accuracy: 0.4897
# Epoch 46/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7710 - accuracy: 0.9344 - val_loss: 2.2189 - val_accuracy: 0.4835
# Epoch 47/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7618 - accuracy: 0.9305 - val_loss: 1.6695 - val_accuracy: 0.5515
# Epoch 48/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7807 - accuracy: 0.9277 - val_loss: 1.8599 - val_accuracy: 0.5498
# Epoch 49/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7715 - accuracy: 0.9326 - val_loss: 2.3248 - val_accuracy: 0.4460
# Epoch 50/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7518 - accuracy: 0.9340 - val_loss: 1.5557 - val_accuracy: 0.5616
# Epoch 51/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7506 - accuracy: 0.9386 - val_loss: 2.2919 - val_accuracy: 0.4620
# Epoch 52/100
# 78/78 [==============================] - 10s 129ms/step - loss: 0.7436 - accuracy: 0.9370 - val_loss: 2.1325 - val_accuracy: 0.4799
# Epoch 53/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7534 - accuracy: 0.9380 - val_loss: 1.7172 - val_accuracy: 0.5566
# Epoch 54/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7349 - accuracy: 0.9407 - val_loss: 1.9333 - val_accuracy: 0.5090
# Epoch 55/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7349 - accuracy: 0.9377 - val_loss: 1.7297 - val_accuracy: 0.5413
# Epoch 56/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7524 - accuracy: 0.9368 - val_loss: 2.6261 - val_accuracy: 0.4266
# Epoch 57/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7347 - accuracy: 0.9431 - val_loss: 1.6630 - val_accuracy: 0.5445
# Epoch 58/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7335 - accuracy: 0.9401 - val_loss: 1.7005 - val_accuracy: 0.5120
# Epoch 59/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7417 - accuracy: 0.9343 - val_loss: 1.7594 - val_accuracy: 0.5228
# Epoch 60/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7378 - accuracy: 0.9394 - val_loss: 1.7497 - val_accuracy: 0.5576
# Epoch 61/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7398 - accuracy: 0.9375 - val_loss: 1.8165 - val_accuracy: 0.5430
# Epoch 62/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7375 - accuracy: 0.9344 - val_loss: 1.7367 - val_accuracy: 0.5458
# Epoch 63/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7426 - accuracy: 0.9356 - val_loss: 2.2633 - val_accuracy: 0.4386
# Epoch 64/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7265 - accuracy: 0.9376 - val_loss: 1.6935 - val_accuracy: 0.5487
# Epoch 65/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7345 - accuracy: 0.9348 - val_loss: 1.9953 - val_accuracy: 0.4677
# Epoch 66/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7219 - accuracy: 0.9413 - val_loss: 1.4833 - val_accuracy: 0.5900
# Epoch 67/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7196 - accuracy: 0.9395 - val_loss: 2.0894 - val_accuracy: 0.4875
# Epoch 68/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7239 - accuracy: 0.9396 - val_loss: 1.6565 - val_accuracy: 0.5620
# Epoch 69/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7248 - accuracy: 0.9351 - val_loss: 2.4483 - val_accuracy: 0.4023
# Epoch 70/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7180 - accuracy: 0.9416 - val_loss: 1.9541 - val_accuracy: 0.5068
# Epoch 71/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7266 - accuracy: 0.9325 - val_loss: 2.0971 - val_accuracy: 0.5040
# Epoch 72/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7167 - accuracy: 0.9394 - val_loss: 2.2511 - val_accuracy: 0.5299
# Epoch 73/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7133 - accuracy: 0.9411 - val_loss: 1.7303 - val_accuracy: 0.5368
# Epoch 74/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7138 - accuracy: 0.9379 - val_loss: 2.9172 - val_accuracy: 0.3505
# Epoch 75/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7069 - accuracy: 0.9387 - val_loss: 2.0200 - val_accuracy: 0.5061
# Epoch 76/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7232 - accuracy: 0.9355 - val_loss: 2.3969 - val_accuracy: 0.4260
# Epoch 77/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7010 - accuracy: 0.9418 - val_loss: 2.0677 - val_accuracy: 0.4812
# Epoch 78/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7149 - accuracy: 0.9365 - val_loss: 1.5274 - val_accuracy: 0.5734
# Epoch 79/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7011 - accuracy: 0.9402 - val_loss: 2.0186 - val_accuracy: 0.4568
# Epoch 80/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7076 - accuracy: 0.9411 - val_loss: 2.1235 - val_accuracy: 0.4431
# Epoch 81/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7106 - accuracy: 0.9363 - val_loss: 1.9441 - val_accuracy: 0.5303
# Epoch 82/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7075 - accuracy: 0.9401 - val_loss: 2.4443 - val_accuracy: 0.4337
# Epoch 83/100
# 78/78 [==============================] - 10s 129ms/step - loss: 0.6967 - accuracy: 0.9436 - val_loss: 1.7388 - val_accuracy: 0.5386
# Epoch 84/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7058 - accuracy: 0.9430 - val_loss: 1.7749 - val_accuracy: 0.5266
# Epoch 85/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6973 - accuracy: 0.9455 - val_loss: 1.8932 - val_accuracy: 0.5230
# Epoch 86/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6955 - accuracy: 0.9417 - val_loss: 2.1154 - val_accuracy: 0.4762
# Epoch 87/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6936 - accuracy: 0.9417 - val_loss: 1.8164 - val_accuracy: 0.5281
# Epoch 88/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6906 - accuracy: 0.9422 - val_loss: 2.1813 - val_accuracy: 0.4786
# Epoch 89/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6933 - accuracy: 0.9434 - val_loss: 2.0318 - val_accuracy: 0.4850
# Epoch 90/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6993 - accuracy: 0.9415 - val_loss: 1.6595 - val_accuracy: 0.5551
# Epoch 91/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.7021 - accuracy: 0.9402 - val_loss: 1.8577 - val_accuracy: 0.5280
# Epoch 92/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.6865 - accuracy: 0.9438 - val_loss: 1.6504 - val_accuracy: 0.5543
# Epoch 93/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6915 - accuracy: 0.9445 - val_loss: 2.1483 - val_accuracy: 0.4447
# Epoch 94/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.7046 - accuracy: 0.9367 - val_loss: 2.1141 - val_accuracy: 0.5271
# Epoch 95/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6829 - accuracy: 0.9416 - val_loss: 1.5977 - val_accuracy: 0.5615
# Epoch 96/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6958 - accuracy: 0.9415 - val_loss: 1.5529 - val_accuracy: 0.5771
# Epoch 97/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6808 - accuracy: 0.9458 - val_loss: 1.8171 - val_accuracy: 0.5170
# Epoch 98/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6788 - accuracy: 0.9460 - val_loss: 2.1206 - val_accuracy: 0.4794
# Epoch 99/100
# 78/78 [==============================] - 10s 127ms/step - loss: 0.6814 - accuracy: 0.9413 - val_loss: 1.9496 - val_accuracy: 0.4913
# Epoch 100/100
# 78/78 [==============================] - 10s 128ms/step - loss: 0.6930 - accuracy: 0.9419 - val_loss: 1.9949 - val_accuracy: 0.5067
# 10000/10000 [==============================] - 3s 314us/step
# Test loss: 1.9949284358978272
# Test accuracy: 0.5066999793052673

# %% [markdown]
# Plot : Accuracy

# %%
import matplotlib.pyplot as plt

plt.figure(0)
plt.plot(plot.history['accuracy'], label='Training Accuracy')
plt.plot(plot.history['val_accuracy'], label='Test Accuracy')
#plt.plot(plot.history['loss'], label='Training Loss')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()

# %% [markdown]
# Plot : Loss

# %%
plt.plot(plot.history['loss'], label='Training Loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
